# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# %matplotlib inline

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
import os

print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: c:\Users\Samee\Documents\MediLens_AI_Project\notebooks

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Samee\Documents\MediLens_AI_Project\notebooks

# %%
import pandas as pd

df = pd.read_csv("../data/diabetes.csv")

print("Dataset loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("../data/diabetes.csv")
#       4
#       5 print("Dataset loaded successfully!")
#
# File c:\Users\Samee\Documents\MediLens_AI_Project\venv311\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Samee\Documents\MediLens_AI_Project\venv311\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Samee\Documents\MediLens_AI_Project\venv311\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Samee\Documents\MediLens_AI_Project\venv311\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\Samee\Documents\MediLens_AI_Project\venv311\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/diabetes.csv'

# %%
import os

for root, dirs, files in os.walk("../"):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# ../data\diabetes\diabetes.csv
# ../venv\Lib\site-packages\matplotlib\mpl-data\sample_data\data_x_x2_x3.csv
# ../venv\Lib\site-packages\matplotlib\mpl-data\sample_data\msft.csv
# ../venv\Lib\site-packages\matplotlib\mpl-data\sample_data\Stocks.csv
# ../venv\Lib\site-packages\numpy\random\tests\data\mt19937-testset-1.csv
# ../venv\Lib\site-packages\numpy\random\tests\data\mt19937-testset-2.csv
# ../venv\Lib\site-packages\numpy\random\tests\data\pcg64-testset-1.csv
# ../venv\Lib\site-packages\numpy\random\tests\data\pcg64-testset-2.csv
# ../venv\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-1.csv
# ../venv\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-2.csv
# ../venv\Lib\site-packages\numpy\random\tests\data\philox-testset-1.csv
# ../venv\Lib\site-packages\numpy\random\tests\data\philox-testset-2.csv
# ../venv\Lib\site-packages\numpy\random\tests\data\sfc64-testset-1.csv
# ../venv\Lib\site-packages\numpy\random\tests\data\sfc64-testset-2.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arccos.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arccosh.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arcsin.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arcsinh.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arctan.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arctanh.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cbrt.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cos.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cosh.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-exp.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-exp2.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-expm1.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log10.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log1p.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log2.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-sin.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-sinh.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-tan.csv
# ../venv\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-tanh.csv
# ../venv\Lib\site-packages\scipy\signal\tests\data\GLB.Ts+dSST.csv
# ../venv\Lib\site-packages\sklearn\datasets\data\breast_cancer.csv
# ../venv\Lib\site-packages\sklearn\datasets\data\iris.csv
# ../venv\Lib\site-packages\sklearn\datasets\data\linnerud_exercise.csv
# ../venv\Lib\site-packages\sklearn\datasets\data\linnerud_physiological.csv
# ../venv\Lib\site-packages\sklearn\datasets\data\wine_data.csv
# ../venv\Lib\site-packages\tornado\test\csv_translations\fr_FR.csv
# ../venv311\Lib\site-packages\matplotlib\mpl-data\sample_data\data_x_x2_x3.csv
# ../venv311\Lib\site-packages\matplotlib\mpl-data\sample_data\msft.csv
# ../venv311\Lib\site-packages\matplotlib\mpl-data\sample_data\Stocks.csv
# ../venv311\Lib\site-packages\numpy\random\tests\data\mt19937-testset-1.csv
# ../venv311\Lib\site-packages\numpy\random\tests\data\mt19937-testset-2.csv
# ../venv311\Lib\site-packages\numpy\random\tests\data\pcg64-testset-1.csv
# ../venv311\Lib\site-packages\numpy\random\tests\data\pcg64-testset-2.csv
# ../venv311\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-1.csv
# ../venv311\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-2.csv
# ../venv311\Lib\site-packages\numpy\random\tests\data\philox-testset-1.csv
# ../venv311\Lib\site-packages\numpy\random\tests\data\philox-testset-2.csv
# ../venv311\Lib\site-packages\numpy\random\tests\data\sfc64-testset-1.csv
# ../venv311\Lib\site-packages\numpy\random\tests\data\sfc64-testset-2.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arccos.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arccosh.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arcsin.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arcsinh.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arctan.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-arctanh.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cbrt.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cos.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-cosh.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-exp.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-exp2.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-expm1.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log10.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log1p.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-log2.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-sin.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-sinh.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-tan.csv
# ../venv311\Lib\site-packages\numpy\_core\tests\data\umath-validation-set-tanh.csv
# ../venv311\Lib\site-packages\sklearn\datasets\data\breast_cancer.csv
# ../venv311\Lib\site-packages\sklearn\datasets\data\iris.csv
# ../venv311\Lib\site-packages\sklearn\datasets\data\linnerud_exercise.csv
# ../venv311\Lib\site-packages\sklearn\datasets\data\linnerud_physiological.csv
# ../venv311\Lib\site-packages\sklearn\datasets\data\wine_data.csv
# ../venv311\Lib\site-packages\tornado\test\csv_translations\fr_FR.csv

# %%
import pandas as pd

df = pd.read_csv("../data/diabetes/diabetes.csv")

print("✅ Dataset loaded successfully!")
# Out:
# ✅ Dataset loaded successfully!

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (768, 9)

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
sns.countplot(x='Outcome', data=df)
plt.title("Diabetes Class Distribution")
plt.show()

# %%
plt.figure(figsize=(10,8))

sns.heatmap(df.corr(),
            annot=True,
            cmap='coolwarm',
            fmt=".2f")

plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(15,8))

sns.boxplot(data=df)

plt.title("Boxplot for Outlier Detection")

plt.xticks(rotation=45)

plt.show()

# %%
from sklearn.preprocessing import StandardScaler

X = df.drop("Outcome", axis=1)
y = df["Outcome"]

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print("Feature Scaling Completed!")

print(X_scaled[:5])
# Out:
# Feature Scaling Completed!
# [[ 0.63994726  0.84832379  0.14964075  0.90726993 -0.69289057  0.20401277
#    0.46849198  1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575  0.53090156 -0.69289057 -0.68442195
#   -0.36506078 -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 -1.28821221 -0.69289057 -1.10325546
#    0.60439732 -0.10558415]
#  [-0.84488505 -0.99820778 -0.16054575  0.15453319  0.12330164 -0.49404308
#   -0.92076261 -1.04154944]
#  [-1.14185152  0.5040552  -1.50468724  0.90726993  0.76583594  1.4097456
#    5.4849091  -0.0204964 ]]

# %%
scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

scaled_df["Outcome"] = y

scaled_df.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.848324       0.149641       0.907270 -0.692891  0.204013
# 1    -0.844885 -1.123396      -0.160546       0.530902 -0.692891 -0.684422
# 2     1.233880  1.943724      -0.263941      -1.288212 -0.692891 -1.103255
# 3    -0.844885 -0.998208      -0.160546       0.154533  0.123302 -0.494043
# 4    -1.141852  0.504055      -1.504687       0.907270  0.765836  1.409746
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.468492  1.425995        1
# 1                 -0.365061 -0.190672        0
# 2                  0.604397 -0.105584        1
# 3                 -0.920763 -1.041549        0
# 4                  5.484909 -0.020496        1
